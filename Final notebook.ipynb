# %% [markdown]
# # Importing necessary liabraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# # Using Foursquare Api

# %%
CLIENT_ID = 'Q5TGBBQYK3Q1VKTMH2Z3GBBQZ5TWEXM0PAG3IOF1YJOV4XKZ' # your Foursquare ID
CLIENT_SECRET = 'SOZVO01F15VC1RFELAX3TR3UFZFQUZG4P3T0JGNGKMXECQJZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Q5TGBBQYK3Q1VKTMH2Z3GBBQZ5TWEXM0PAG3IOF1YJOV4XKZ
# CLIENT_SECRET:SOZVO01F15VC1RFELAX3TR3UFZFQUZG4P3T0JGNGKMXECQJZ

# %% [markdown]
# # Getting Colleges in 5 localities

# %%
search_query = 'College & University'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# College & University .... OK!

# %%
address_1 = ' Sadashiv Peth'

geolocator = Nominatim(user_agent="foursquare_agent")
location_1 = geolocator.geocode(address_1)
latitude_1 = location_1.latitude
longitude_1 = location_1.longitude
print(latitude_1, longitude_1)
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_1, longitude_1, VERSION, search_query, radius, LIMIT)
url
results_1 = requests.get(url).json()

venues_1 = results_1['response']['venues']
# Out:
# 18.5107764 73.8502149

# %%
# tranform venues into a dataframe
dataframe_1 = json_normalize(venues_1)
dataframe_1=dataframe_1[dataframe_1.name != 'Cafe Coffee Day']
dataframe_1=dataframe_1[dataframe_1.name != 'SP College Post Office']
dataframe_1=dataframe_1[dataframe_1.name != 'S P College Ground']
dataframe_1
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                               name  \
# 0  4e1fc5c41838712abe601b1f                      S. P. College
# 2  4f8b811ae4b060b7f958c018  Susheela Bahudhani Junior College
# 3  4f6fb066e4b07fa2c7b92ae8          Fergusson College Library
# 5  517b53d7e4b0a2c664f9378d            Appasaheb Jedhe College
# 6  4f8cf963e4b013a983c6562a                   Naralkar college
# 7  514357f7e4b0c9f1c4724252                      H. V. College
# 8  4fa77c9ce4b0fed48347c63d                   Garaware college
# 9  54672136498e64b49d63539c                        SGS College
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...  v-1591422984    False
# ...

# %%
dataframe_1.shape
# Out:
# (8, 17)

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_1.columns if col.startswith('location.')] + ['id']
data_1= dataframe_1.loc[:, filtered_columns]


def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_1['categories'] = data_1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_1.columns = [column.split('.')[-1] for column in data_1.columns]

data_1.head()
# Out:
#                                 name                    categories  \
# 0                      S. P. College  General College & University
# 2  Susheela Bahudhani Junior College      College Science Building
# 3          Fergusson College Library               College Library
# 5            Appasaheb Jedhe College     College Academic Building
# 6                   Naralkar college  General College & University
#
#                 address        lat        lng  \
# 0            Tilak Road  18.507308  73.849743
# 2                   NaN  18.509703  73.854295
# 3  Fergusson College Rd  18.510061  73.846469
# 5                   NaN  18.507734  73.856415
# 6                   NaN  18.517000  73.853533
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 18.50730817151161...       389     411030  IN
# 2  [{'label': 'display', 'lat': 18.50970270661543...       446        NaN  IN
# ...

# %%
import folium
venues_map = folium.Map(location=[latitude_1, longitude_1], zoom_start=12) 

folium.features.CircleMarker(
    [latitude_1, longitude_1],
    radius=10,
    color='red',
    popup='Sadashiv Peth',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


for lat, lng, label in zip(data_1.lat, data_1.lng, data_1.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. Katraj

# %%
address_2 = 'katraj'

geolocator = Nominatim(user_agent="foursquare_agent")
location_2 = geolocator.geocode(address_2)
latitude_2 = location_2.latitude
longitude_2 = location_2.longitude
print(latitude_2, longitude_2)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2, VERSION, search_query, radius, LIMIT)

results_2 = requests.get(url).json()
venues_2 = results_2['response']['venues']

# tranform venues into a dataframe
dataframe_2 = pd.json_normalize(venues_2)
dataframe_2=dataframe_2[dataframe_2.name !='college cream cafe']
dataframe_2
# Out:
# 18.4536792 73.8563196
#                          id  \
# 0  4c68cc6fe89fb7132243ce21
# 1  4e0dabe245ddc2c6d16f8811
# 3  4f98ea0fe4b00ba71271c7b2
# 4  4f67fe77e4b0289eb1643100
# 5  4d86d7e261676dcbe1a4a8e4
# 6  4d85fa21353060fca7a30de3
# 7  503325a6e4b0d660de57b9f9
# 8  4cf7f81464e3721e7b8329c8
#
#                                                 name  \
# 0          Bharati Vidyapeeth College of Engineering
# 1                  Bharati vidyapeet medical college
# 3                Bhartiya Vidyapeeth College of Arts
# 4   Vishwakarma College of Arts Commerce and Science
# 5  Dept Of Pedo,Bharati Vidyapeeth Dental College...
# 6     Bharati Vidyapeeth Dental College And Hospital
# 7         Bharati Vidyapeeth College Of Architecture
# 8              Pune Institute of Computer Technology
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d19e941735', 'name': 'C...  v-1591422985    False
# ...

# %%
dataframe_2.shape
# Out:
# (8, 17)

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_2.columns if col.startswith('location.')] + ['id']
data_2 = dataframe_2.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_2['categories'] = data_2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_2.columns = [column.split('.')[-1] for column in data_2.columns]

data_2.head()
# Out:
#                                                 name  \
# 0          Bharati Vidyapeeth College of Engineering
# 1                  Bharati vidyapeet medical college
# 3                Bhartiya Vidyapeeth College of Arts
# 4   Vishwakarma College of Arts Commerce and Science
# 5  Dept Of Pedo,Bharati Vidyapeeth Dental College...
#
#                         categories             address            crossStreet  \
# 0     College Engineering Building          Dhankawadi       Pune-Satara Road
# 1        College Academic Building              katraj  pune-banglore highway
# 3            College Arts Building                 NaN                    NaN
# 4  College Communications Building  Upper Indira Nagar        Kondhwa Budhruk
# 5                   Medical School                 NaN                    NaN
#
#          lat        lng                                     labeledLatLngs  \
# 0  18.458002  73.855348  [{'label': 'display', 'lat': 18.45800167635982...
# ...

# %%
folium.features.CircleMarker(
    [latitude_2, longitude_2],
    radius=10,
    color='red',
    popup='Katraj',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(data_2.lat, data_2.lng, data_2.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3. Kothrud

# %%
address_3 = 'Kothrud'

geolocator = Nominatim(user_agent="foursquare_agent")
location_3 = geolocator.geocode(address_3)
latitude_3 = location_3.latitude
longitude_3 = location_3.longitude
print(latitude_3, longitude_3)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_3, longitude_3, VERSION, search_query, radius, LIMIT)

results_3 = requests.get(url).json()
venues_3 = results_3['response']['venues']
dataframe_3 = pd.json_normalize(venues_3)
dataframe_3
# Out:
# 18.5038889 73.807673
#                          id                                       name  \
# 0  4f5ad0e6e4b0d8f7b57e230c       Kaveri College of Science & Commerce
# 1  4ebe4d3029c25ce5a147767c  Maharashtra College of Science & Commerce
# 2  4eabec530aafb00bd928fbfe                              Unity College
# 3  4e9967e97ee571e1ee91fda0                 Yashwantrao mohite college
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...  v-1591422986    False
# 1  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...  v-1591422986    False
# 2  [{'id': '4bf58dd8d48988d19b941735', 'name': 'C...  v-1591422986    False
# 3  [{'id': '4bf58dd8d48988d199941735', 'name': 'C...  v-1591422986    False
#
#                      location.address  location.lat  location.lng  \
# 0  Ganesh Nagar,Near CDSS,Erandawane.     18.507861     73.802846
# 1             Rambaug Colony, Kothrud     18.510932     73.811542
# ...

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_3.columns if col.startswith('location.')] + ['id']
data_3 = dataframe_3.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_3['categories'] = data_3.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_3.columns = [column.split('.')[-1] for column in data_3.columns]

data_3
# Out:
#                                         name                 categories  \
# 0       Kaveri College of Science & Commerce  College Academic Building
# 1  Maharashtra College of Science & Commerce  College Academic Building
# 2                              Unity College   College Science Building
# 3                 Yashwantrao mohite college      College Arts Building
#
#                               address        lat        lng  \
# 0  Ganesh Nagar,Near CDSS,Erandawane.  18.507861  73.802846
# 1             Rambaug Colony, Kothrud  18.510932  73.811542
# 2   DP Rd, Kothrud, Pune, Maharashtra  18.502152  73.802305
# 3                                 NaN  18.512119  73.807039
#
#                                       labeledLatLngs  distance  cc  city  \
# 0  [{'label': 'display', 'lat': 18.50786149780025...       674  IN  Pune
# 1  [{'label': 'display', 'lat': 18.51093244075384...       884  IN  Pune
# 2  [{'label': 'display', 'lat': 18.50215172703697...       598  IN  Pune
# ...

# %%
dataframe_3.shape
# Out:
# (4, 15)

# %%
folium.features.CircleMarker(
    [latitude_3, longitude_3],
    radius=10,
    color='red',
    popup='Kothrud',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(data_3.lat, data_3.lng, data_3.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='yellow',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Gadital(Hadapsar)

# %%
address_4 = 'Gadital'

geolocator = Nominatim(user_agent="foursquare_agent")
location_4 = geolocator.geocode(address_4)
latitude_4 = location_4.latitude
longitude_4= location_4.longitude
print(latitude_4, longitude_4)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_4, longitude_4, VERSION, search_query, 3000, LIMIT)
# Out:
# 18.5004025 73.9390426096752

# %%
results_4 = requests.get(url).json()
venues_4 = results_4['response']['venues']

dataframe_4 = pd.json_normalize(venues_4)
dataframe_4
# Out:
#                          id                                      name  \
# 0  513195c0e4b03fa973360ec7                        PDEA's Law College
# 1  51973ad0498eda390752a42b                Sadhana college room no 19
# 2  519735d0498e3d8c9b3e3107  Chandrabhag baburao tupe sadhana college
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...  v-1591422987    False
# 1  [{'id': '4bf58dd8d48988d1a0941735', 'name': 'C...  v-1591422987    False
# 2  [{'id': '4bf58dd8d48988d197941735', 'name': 'C...  v-1591422987    False
#
#    location.lat  location.lng  \
# 0     18.502013     73.944050
# 1     18.505498     73.937397
# 2     18.508527     73.940059
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.50201316141466...                558
# 1  [{'label': 'display', 'lat': 18.50549834869, '...                593
# ...

# %%
dataframe_4.shape
# Out:
# (3, 15)

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_4.columns if col.startswith('location.')] + ['id']
data_4 = dataframe_4.loc[:, filtered_columns]


def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_4['categories'] = data_4.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_4.columns = [column.split('.')[-1] for column in data_4.columns]

data_4
# Out:
#                                        name                       categories  \
# 0                        PDEA's Law College        College Academic Building
# 1                Sadhana college room no 19                College Classroom
# 2  Chandrabhag baburao tupe sadhana college  College Administrative Building
#
#          lat        lng                                     labeledLatLngs  \
# 0  18.502013  73.944050  [{'label': 'display', 'lat': 18.50201316141466...
# 1  18.505498  73.937397  [{'label': 'display', 'lat': 18.50549834869, '...
# 2  18.508527  73.940059  [{'label': 'display', 'lat': 18.508527, 'lng':...
#
#    distance  cc country                          formattedAddress   address  \
# 0       558  IN   India                                   [India]       NaN
# 1       593  IN   India               [Hadapsar, Hasapsar, India]  Hadapsar
# 2       910  IN   India  [Hadapsar, Hadapsar, Mahārāshtra, India]  Hadapsar
#
# ...

# %%
folium.features.CircleMarker(
    [latitude_4, longitude_4],
    radius=10,
    color='red',
    popup='Hadapsar',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(data_4.lat, data_4.lng, data_4.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='violet',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Narhe

# %%
address_5 = 'narhe'

geolocator = Nominatim(user_agent="foursquare_agent")
location_5 = geolocator.geocode(address_5)
latitude_5= location_5.latitude
longitude_5= location_5.longitude
print(latitude_5, longitude_5)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_5, longitude_5, VERSION, search_query, 2000, LIMIT)
# Out:
# 18.4501246 73.8197569

# %%
results_5 = requests.get(url).json()
venues_5 = results_5['response']['venues']

dataframe_5 = pd.json_normalize(venues_5)
dataframe_5
# Out:
#                          id  \
# 0  4df6d327b61c40d585eaf4a9
# 1  4fd5960ae4b01a8123a78e1f
# 2  4e5b42e6d4c0ba8c11b572e4
# 3  4fde2612e4b090d3f656d95a
# 4  4fcaf791e4b0d376cb8f5d61
# 5  4ed081e0f5b9832ada5a0ace
# 6  4e684267b0fb8e94c7ba7fb9
#
#                                                 name  \
# 0  Smt. Kashibai Navale Medical College & General...
# 1                                      College Katta
# 2                                       Zeal college
# 3                 Sinhgad Medical College Tea Corner
# 4                                Sinhgad Law College
# 5                           Abhinav Pharmacy College
# 6                                   Sinhagad college
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1b3941735', 'name': 'M...  v-1591422988    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1591422988    False
# ...

# %%
dataframe_5.shape
# Out:
# (7, 17)

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_5.columns if col.startswith('location.')] + ['id']
data_5 = dataframe_5.loc[:, filtered_columns]


def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_5['categories'] = data_5.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_5.columns = [column.split('.')[-1] for column in data_5.columns]

data_5
# Out:
#                                                 name  \
# 0  Smt. Kashibai Navale Medical College & General...
# 1                                      College Katta
# 2                                       Zeal college
# 3                 Sinhgad Medical College Tea Corner
# 4                                Sinhgad Law College
# 5                           Abhinav Pharmacy College
# 6                                   Sinhagad college
#
#                      categories  \
# 0                Medical School
# 1             Indian Restaurant
# 2  General College & University
# 3                          Café
# 4                    Law School
# 5      College Science Building
# 6     College Academic Building
#
#                                              address        lat        lng  \
# 0  S.No. 49/1, Westerly Bypass Road, Narhe (Ambeg...  18.456609  73.820095
# 1                                                NaN  18.460188  73.824234
# ...

# %%
folium.features.CircleMarker(
    [latitude_5, longitude_5],
    radius=10,
    color='red',
    popup='Pashan',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(data_5.lat, data_5.lng, data_5.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Getting Coffee Shops in 5 localities

# %%
search_query = 'Coffee'

# %%
radius=1000

# %% [markdown]
# ## 1. Sadashiv Peth

# %%
address_1 = ' Sadashiv Peth'

geolocator = Nominatim(user_agent="foursquare_agent")
location_1 = geolocator.geocode(address_1)
latitude_1 = location_1.latitude
longitude_1 = location_1.longitude
print(latitude_1, longitude_1)
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_1, longitude_1, VERSION, search_query, radius, LIMIT)
url
results_1 = requests.get(url).json()

venues_1 = results_1['response']['venues']
dataframe_1 = json_normalize(venues_1)
dataframe_1
# Out:
# 18.5107764 73.8502149
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   del sys.path[0]
#                          id                               name  \
# 0  4d3be9fb6b3d236a58875c64                    Cafe Coffee Day
# 1  50f2d1e4e4b0d13e7e922e62  Smile Fresh - A Cold Coffee House
# 2  5638d88fcd102f70588d6c0c                    cafe Coffee day
# 3  4c1f3ec1e923ef3b0fb34e54      Cafe Coffee Day, Nucleus Mall
# 4  56b3029e498e81b5613649d9                Rohit Coffee Corner
# 5  545c7eac498e988eacb56948                         Coffee Jar
# 6  4f0713bfe4b07c8f8aa41279                  Swami Cold Coffee
# 7  4fa279eae4b09588d3bf56d7                   cafe coffee shop
# 8  4e9c36bb6da1cbe0b9064bab              Gloria Jean's Coffees
#
#                                           categories    referralId  hasPerk  \
# ...

# %%
dataframe_1.shape
# Out:
# (9, 17)

# %% [markdown]
# ## 2. Katraj

# %%
address_2 = 'katraj'

geolocator = Nominatim(user_agent="foursquare_agent")
location_2 = geolocator.geocode(address_2)
latitude_2 = location_2.latitude
longitude_2 = location_2.longitude
print(latitude_2, longitude_2)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2, VERSION, search_query, radius, LIMIT)

results_2 = requests.get(url).json()
venues_2 = results_2['response']['venues']

# tranform venues into a dataframe
dataframe_2 = pd.json_normalize(venues_2)

dataframe_2
# Out:
# 18.4536792 73.8563196
#                          id                 name  \
# 0  4c134914583c9c7493673fa4      Cafe Coffee Day
# 1  5693d21e498ea42fee51d508     Riya Cold Coffee
# 2  4fcbb03ee4b0e6dca8037352  S. Baba Coffee Stop
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591422990    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1591422990    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591422990    False
#
#                  location.address location.crossStreet  location.lat  \
# 0  Bharti Vidyapeeth Back Market,               Katraj     18.457249
# 1                             NaN                  NaN     18.457359
# 2                             NaN                  NaN     18.456648
#
#    location.lng                            location.labeledLatLngs  \
# 0     73.851759  [{'label': 'display', 'lat': 18.45724945200827...
# ...

# %%
dataframe_2.shape
# Out:
# (3, 16)

# %% [markdown]
# ## 3. Kothrud

# %%
address_3 = 'Kothrud'

geolocator = Nominatim(user_agent="foursquare_agent")
location_3 = geolocator.geocode(address_3)
latitude_3 = location_3.latitude
longitude_3 = location_3.longitude
print(latitude_3, longitude_3)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_3, longitude_3, VERSION, search_query, radius, LIMIT)

results_3 = requests.get(url).json()
venues_3 = results_3['response']['venues']
dataframe_3 = pd.json_normalize(venues_3)
dataframe_3
# Out:
# 18.5038889 73.807673
#                          id                                    name  \
# 0  4f10405fe4b047204368798c                      Muktai Coffee Shop
# 1  50e80ad8e4b0b1ba6c38f6e4                            Coffee Katta
# 2  536517b3498ed675cec327ad                            Durga Coffee
# 3  4ecb52af6da19ab5eee7045b                  Cafe Coffee Day, Surat
# 4  50d0a99ee4b0c73513052191                    Samartha Coffee Shop
# 5  4cbad9657148f04d2deadeab                         Cafe Coffee Day
# 6  4ef9e899775b54cdb69468db  Kumaradhara Traders - Coffee Merchants
# 7  4b9fbbfdf964a520ae3937e3                         Cafe Coffee Day
# 8  4f47ea03e4b0d637407193fd                         Cafe Coffee Day
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1591422991    False
# 1  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...  v-1591422991    False
# ...

# %%
dataframe_3.shape
# Out:
# (9, 17)

# %% [markdown]
# ## 4. Hadapsar

# %%
address_4 = 'Hadapsar'

geolocator = Nominatim(user_agent="foursquare_agent")
location_4 = geolocator.geocode(address_4)
latitude_4 = location_4.latitude
longitude_4= location_4.longitude
print(latitude_4, longitude_4)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_4, longitude_4, VERSION, search_query, radius, LIMIT)

results_4 = requests.get(url).json()
venues_4 = results_4['response']['venues']

dataframe_4 = json_normalize(venues_4)
dataframe_4
# Out:
# 18.526967 73.9278252
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                               name  \
# 0  530e2cd811d213227811fd70                        Coffee Tree
# 1  52cbbc99498e0d514226d3f3       Cafe Coffee Day - The Lounge
# 2  4dee3cbcc65bf34fc6e74dd7      @M Coffee Shop And Restaurant
# 3  5321c816498ec5ca31cf7800  Starbucks Coffee: A Tata Alliance
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1591422992    False
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591422992    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1591422992    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591422992    False
#
#    location.lat  location.lng  \
# 0     18.518951     73.931220
# ...

# %%
dataframe_4.shape
# Out:
# (4, 17)

# %% [markdown]
# ## 5. Narhe

# %%
address_5 = 'Narhe'
5
geolocator = Nominatim(user_agent="foursquare_agent")
location_5 = geolocator.geocode(address_5)
latitude_5= location_5.latitude
longitude_5= location_5.longitude
print(latitude_5, longitude_5)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_5, longitude_5, VERSION, search_query, 1500, LIMIT)
# Out:
# 18.4501246 73.8197569

# %%
results_5 = requests.get(url).json()
venues_5 = results_5['response']['venues']

dataframe_5 = pd.json_normalize(venues_5)
dataframe_5
# Out:
#                          id                   name  \
# 0  50da9bb1e4b0cc0be43b42db  sinhgad coffee corner
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1591422992    False
#
#    location.lat  location.lng  \
# 0     18.455542     73.818497
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.45554161071777...                617
#
#   location.cc location.country location.formattedAddress
# 0          IN            India                   [India]

# %%
dataframe_5.shape
# Out:
# (1, 12)

# %% [markdown]
# # Comparison
# ### We make a table from the data of no. of Colleges and Coffee shops that we have got by using fuction dataframe.shape

# %% [markdown]
# |   Locality    | No. of Colleges | No. of Coffee shops |
# |---------------|-----------------|---------------------|
# | Sadashiv Peth |        8        |         9           |
# |   Katraj      |        8        |         3           |
# |  Kothrud      |        4        |         9           |
# |  Hadapsar     |        3        |         4           |
# |  Narhe        |        7        |         7           |

# %% [markdown]
# # Observations:
# 1.We observe that no. of colleges is highest in 'Sadashiv Peth' and 'Katraj'.
#
# 2.We also observe that no. of coffee shops is least in 'Katraj'.
# # Conclusion:
# As it is favourable for the businessperson to choose a location with higher no. of colleges and lower no. of already present coffee shops; 'Katraj' would be the solution. Katraj has highest no. of colleges and least no. of coffee shops.
#
# Thus, **'Katraj'** is the right place to choose for opening a new coffee shop.

# %% [markdown]
# ## Plotting map of Katraj with its Colleges and Coffee shops

# %%
search_query= 'College & Universities'

# %%
address_2 = 'katraj'

geolocator = Nominatim(user_agent="foursquare_agent")
location_2 = geolocator.geocode(address_2)
latitude_2 = location_2.latitude
longitude_2 = location_2.longitude
print(latitude_2, longitude_2)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2, VERSION, search_query, radius, LIMIT)

results_2 = requests.get(url).json()
venues_2 = results_2['response']['venues']

# tranform venues into a dataframe
dataframe_2 = pd.json_normalize(venues_2)
dataframe_2=dataframe_2[dataframe_2.name !='college cream cafe']
# Out:
# 18.4536792 73.8563196

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_2.columns if col.startswith('location.')] + ['id']
data_2 = dataframe_2.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_2['categories'] = data_2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_2.columns = [column.split('.')[-1] for column in data_2.columns]

# %%
venues_map_2 = folium.Map(location=[latitude_2, longitude_2], zoom_start=15)
folium.features.CircleMarker(
    [latitude_2, longitude_2],
    radius=10,
    color='red',
    popup='Katraj',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map_2)

for lat, lng, label in zip(data_2.lat, data_2.lng, data_2.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map_2)

# %%
search_query='Coffee'

# %%
address_2 = 'katraj'

geolocator = Nominatim(user_agent="foursquare_agent")
location_2 = geolocator.geocode(address_2)
latitude_2 = location_2.latitude
longitude_2 = location_2.longitude
print(latitude_2, longitude_2)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2, VERSION, search_query, radius, LIMIT)

results_2 = requests.get(url).json()
venues_2 = results_2['response']['venues']

# tranform venues into a dataframe
dataframe_2 = pd.json_normalize(venues_2)
# Out:
# 18.4536792 73.8563196

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe_2.columns if col.startswith('location.')] + ['id']
data_02 = dataframe_2.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
data_02['categories'] = data_02.apply(get_category_type, axis=1)

# clean column names by keeping only last term
data_02.columns = [column.split('.')[-1] for column in data_02.columns]

# %%
for lat, lng, label in zip(data_02.lat, data_02.lng, data_02.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='yellow',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map_2)
venues_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# By referring to this map its very easy to search for available location for coffee shop.
